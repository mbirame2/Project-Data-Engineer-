# %%
import pandas as pd
import re
from fuzzywuzzy import fuzz

# %% [markdown]
# # Fonction pour nettoyer les noms des clubs

# %%
def clean_name(name):
   
    suffixes = r'\s*(FC|Club|SFC|SPFC|RET|Bait Jair|Sports Club|Sporting|Mohammedein FC)$'
    cleaned = re.sub(suffixes, '', str(name), flags=re.IGNORECASE)
    return cleaned.lower().strip()

# %% [markdown]
# # Fonction pour regroupement des noms d'équipes similaires (Exemple Al-Nassr FC, Nassr	→	Al-Nassr FC)

# %%
def standardize_team_names(df):
    # On récupère tous les noms d'équipes
    all_team_names = []
    for col in ['provider_1_team_name', 'provider_2_team_name', 'provider_3_team_name']:
        for name in df[col].dropna().unique():
            if name not in all_team_names:  # Évite les doublons
                all_team_names.append(name)
    
    # On prépare une liste pour stocker nos groupes d'équipes
    clusters = []
    
    SEUIL_SIMILARITE = 85 
    
    # On va traiter chaque nom un par un
    for name in all_team_names:
        trouve = False
        
        # On nettoie le nom  
        cleaned_name = clean_name(name)
        
        # On cherche si ça matche avec un groupe existant
        for cluster in clusters:
            # On prend le premier nom du groupe comme référence
            ref_name = cluster[0]
            cleaned_ref = clean_name(ref_name)
            
            # Calcul de la similarité avec fuzzy
            score = fuzz.partial_ratio(cleaned_name, cleaned_ref)
            
            if score > SEUIL_SIMILARITE:
                cluster.append(name)
                trouve = True
                break
        
        # Si on a rien trouvé, on crée un nouveau groupe
        if not trouve:
            clusters.append([name])
    
    # Maintenant on crée le mapping pour la standardisation
    name_mapping = {}
    for cluster in clusters:
        # On choisit le nom le plus long comme standard souvent le plus complet
        standard = max(cluster, key=len)
        
        # On ajoute chaque variante au mapping
        for variant in cluster:
            name_mapping[variant] = standard
    
    return name_mapping

# %%
def main():
    df = pd.read_excel('data/file_ASM.xlsx', sheet_name='club_names_ids')
    
    name_mapping = standardize_team_names(df)
    print(name_mapping)
    print("____________________________________________________________________")
    # Appliquer le mapping
    df['standard_team_name'] = df['provider_1_team_name'].map(name_mapping)
    
    # Sauvegarder le résultat
    df.to_excel('cleaned_teams_BM.xlsx', index=False)
    print("Standardisation terminée. Résultats sauvegardés dans 'cleaned_teams_BM.xlsx'")

if __name__ == "__main__":
    main()
# Out:
# {'Al-Nassr FC': 'Al-Nassr FC', 'Al-Nassr': 'Al-Nassr FC', 'Nassr': 'Al-Nassr FC', 'Al-Ittihad Club': 'Al-Ittihad Club', 'Al-Ittihad': 'Al-Ittihad Club', 'Ittihad': 'Al-Ittihad Club', 'Al-Shabab': 'Al-Shabab', 'Shabab': 'Al-Shabab', 'Al-Hilal SFC': 'Al-Hilal SFC', 'Al-Hilal': 'Al-Hilal SFC', 'Hilal': 'Al-Hilal SFC', 'Al-Taawoun FC': 'Taawoun Sports Club', 'Al-Taawoun RET': 'Taawoun Sports Club', 'Taawoun Sports Club': 'Taawoun Sports Club', 'Al-Fateh': 'Fateh Sporting', 'Fateh Sporting': 'Fateh Sporting', 'Damac FC': 'Damac Sporting FC', 'Damac': 'Damac Sporting FC', 'Damac Sporting FC': 'Damac Sporting FC', 'Al-Tai': 'Al-Tai', 'Tai FC': 'Al-Tai', 'Abha': 'Abha FC', 'Abha FC': 'Abha FC', 'Al-Raed': 'Al-Raed', 'Raed FC': 'Al-Raed', 'Al-Fayha': 'Al-Fayha', 'Fayha FC': 'Al-Fayha', 'Ettifaq FC': 'Ettifaq FC', 'Al-Ettifaq': 'Ettifaq FC', 'Al-Wehda FC': 'Al-Wehda SPFC', 'Al-Wehda SPFC': 'Al-Wehda SPFC', 'Wehda FC': 'Al-Wehda SPFC', 'Khaleej': 'Al-Khaleej', 'Al-Khaleej': 'Al-Khaleej', 'Khaleej FC': 'Al-Khaleej', 'Al-Adalah FC': 'Al-Adalah FC', 'Al-Adalah': 'Al-Adalah FC', 'Adalah FC': 'Al-Adalah FC', 'Al-Batin FC': 'Al-Batin FC', 'Al-Batin': 'Al-Batin FC', 'Batin FC': 'Al-Batin FC', 'Al-Qadsiah FC': 'Al-Qadsiah FC', 'Qadsiah': 'Al-Qadsiah FC', 'Qadsiah Club': 'Al-Qadsiah FC', 'Al-Hazem FC': 'Al-Hazem FC', 'Hazem': 'Al-Hazem FC', 'Hazem Club': 'Al-Hazem FC', 'Ohod FC': 'Ohod Club', 'Ohod': 'Ohod Club', 'Ohod Club': 'Ohod Club', 'Najran FC': 'Najran Club', 'Najran': 'Najran Club', 'Najran Club': 'Najran Club', 'Al-Ain FC': 'Al-Ain FC', 'Ain': 'Al-Ain FC', 'Ain Club': 'Al-Ain FC', 'Al-Kawkab FC': 'Al-Kawkab FC', 'Kawkab': 'Al-Kawkab FC', 'Kawkab Club': 'Al-Kawkab FC', 'Hajer FC': 'Hajer Club', 'Hajer': 'Hajer Club', 'Hajer Club': 'Hajer Club', 'Al-Nahda FC': 'Al-Nahda FC', 'Nahda': 'Al-Nahda FC', 'Nahda Club': 'Al-Nahda FC', 'Al-Jabalain FC': 'Al-Jabalain FC', 'Jabalain': 'Al-Jabalain FC', 'Al-Nojoom FC': 'Nojoom Bait Jair', 'Nojoom Bait Jair': 'Nojoom Bait Jair', 'Nojoom Club': 'Nojoom Bait Jair', 'Al-Ansar FC': 'Al-Ansar FC', 'Ansar': 'Al-Ansar FC', 'Ansar Club': 'Al-Ansar FC', 'Al-Taqadom FC': 'Al-Taqadom FC', 'Taqadom': 'Al-Taqadom FC', 'Taqadom Club': 'Al-Taqadom FC', 'Al-Diriyah FC': 'Diriyah Mohammedein FC', 'Diriyah Mohammedein FC': 'Diriyah Mohammedein FC', 'Diriyah Club': 'Diriyah Mohammedein FC', 'Al-Jeel FC': 'Al-Jeel FC', 'Jeel': 'Al-Jeel FC', 'Jeel Club': 'Al-Jeel FC', "Al-Ta'ee": "Al-Ta'ee", 'Jabalain Club Lala': 'Jabalain Club Lala'}
# Standardisation terminée. Résultats sauvegardés dans 'cleaned_teams_BM.xlsx'
